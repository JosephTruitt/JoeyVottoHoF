# %% [markdown]
# # Is Joey Votto a Hall of Famer?
#
# ## Introduction:
# With the likely retirement of Joey Votto in this upcoming off-season, he has been a great player for the  entirety of his career. The baseball world quickly has come to argue, is he a hall of famer? Let us compare his stats to other players in the Hall of Fame to see where he stands.
#
# ## Hall of Fame Data:
# All data was gathered from baseball-reference.com. Although not all this data is equally important or valuable, all these statistics are commonly used as evidence of whether a player should or shouldn't be in the Hall of Fame.
#
# Yrs: Years the player has been in the major leagues. <br>
# ASG: All-Star Game selections<br>
# WAR/pos: Total wins added above replacement level. An easy and fundamental way to attribute the total value a player has added to his team<br>
# H: Hits<br>
# R: Runs scored<br>
# HR: Home runs<br>
# RBI: Runs batted in<br>
# BB: Base on balls (walks)
# BA: Batting Average<br>
# OBP: On-base percentage <br>
# OPS: On base percentage + slugging percentage<br>
#
# ## Asking Questions
#
# What are Votto's highlights of his resume? Lowlights?
# Will Votto make the Hall of Fame?
# Should he make the Hall of Fame?
#
# ## Accessing Data
#
# We import libraries and load our dataset.<br>
# The data set is the batting stats for all Hall of Fame batters.<br>

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load CSV
batter_data = pd.read_excel('sportsref_download2.xlsx')

# Preview of data
batter_data.head()
# Out:
#     Rk              Name  Inducted  Yrs  From    To  ASG  WAR/pos     G  \
# 0  1.0       Henry Aaron    1982.0   23  1954  1976   25    143.0  3298
# 1  2.0  Grover Alexander    1938.0   20  1911  1930    0      3.1   703
# 2  3.0    Roberto Alomar    2011.0   17  1988  2004   12     67.0  2379
# 3  4.0     Walter Alston    1983.0    1  1936  1936    0      0.0     1
# 4  5.0   Sparky Anderson    2000.0    1  1959  1959    0     -1.2   152
#
#       PA  ...    BB      SO    IBB    GDP     SF     SH     BA    OBP    SLG  \
# 0  13941  ...  1402  1383.0  293.0  328.0  121.0   21.0  0.305  0.374  0.555
# 1   1981  ...    77   276.0    0.0    NaN    NaN   88.0  0.209  0.242  0.275
# 2  10400  ...  1032  1140.0   62.0  206.0   97.0  148.0  0.300  0.371  0.443
# 3      1  ...     0     1.0    0.0    0.0    NaN    0.0  0.000  0.000  0.000
# 4    527  ...    42    53.0    1.0   15.0    2.0    5.0  0.218  0.282  0.249
#
#      OPS
# 0  0.928
# 1  0.517
# 2  0.814
# 3  0.000
# 4  0.531
#
# ...

# %% [markdown]
# ## Cleaning Data
# In baseball, not all positions are created equally. Some positions are much harder to play than others, thus greater skill is needed in those positions for defense so they can get away with not being great hitters. Joey Votto's position, first base, is one of the easiest to play. Thus, higher offensive numbers are expected from them. <br>
#
# We compare Joey Votto to all other players in the Hall of Fame at his position because comparing him to all players may make him look better than he really was if we compare him to players who played more intensive defensive positions, thus requiring less batting ability to be inducted in the Hall of Fame.

# %%
batter_data = pd.DataFrame(batter_data)

# List of HoF 1B
First_Base = ['Cap Anson', 'Jeff Bagwell', 'Jake Beckley', 'Jim Bottomley', 'Dan Brouthers', 'Orlando Cepeda', 'Frank Chance', 'Roger Connor', 'Jimmie Foxx', 'Lou Gehrig', 'Hank Greenberg', 'Gil Hodges', 'George Kelly', 'Harmon Killebrew', 'Willie McCovey', 'Fred McGriff', 'Johnny Mize', 'Eddie Murray', 'Stan Musial', 'Tony Perez', 'George Sisler', 'Bill Terry', 'Frank Thomas', 'Jim Thome']

# Creating table of just 1B players
FirstBaseman = df[df['Name'].isin(First_Base)]
print(FirstBaseman)
# Out:
#         Rk              Name  Inducted  Yrs  From    To  ASG  WAR/pos     G  \
# 5      6.0         Cap Anson    1939.0   27  1871  1897    0     94.4  2524
# 10    11.0      Jeff Bagwell    2017.0   15  1991  2005    4     79.9  2150
# 15    16.0      Jake Beckley    1971.0   20  1888  1907    0     61.5  2392
# 23    24.0     Jim Bottomley    1974.0   16  1922  1937    0     35.8  1991
# 28    29.0     Dan Brouthers    1945.0   19  1879  1904    0     79.8  1676
# 39    40.0    Orlando Cepeda    1999.0   17  1958  1974   11     50.1  2124
# 40    41.0      Frank Chance    1946.0   17  1898  1914    0     46.0  1288
# 53    54.0      Roger Connor    1976.0   18  1880  1897    0     84.3  1998
# 87    88.0       Jimmie Foxx    1951.0   20  1925  1945    9     92.2  2317
# 90    91.0        Lou Gehrig    1939.0   17  1923  1939    7    113.8  2164
# 99   100.0    Hank Greenberg    1956.0   13  1930  1947    5     55.4  1394
# ...

# %% [markdown]
# ## Analyzing Data
# Let us look at how Joey Votto fared against these players in some key stats.

# %%
# Import Joey Votto's stats
JoeyVotto = [['Yrs', 17],['ASG', 6],['WAR/pos', 64.5],['R', 1171],['H', 2135],['HR', 356],['RBI', 1144],['SB', 80],['BB', 1365],['BA', .294],['OBP', .409],['OPS', .920]]

# Creating boxplot for years played with Joey Votto a point on the boxplot
FirstBaseman.boxplot(column='Yrs')
plt.scatter(1, 17)
plt.show()
JoeyVottoYrs = stats.percentileofscore(FirstBaseman['Yrs'], 17)

# %% [markdown]
# Joey Votto had a career length below the median (39th percentile). The main reason for this analysis is to get a baseline when looking at counting stats. All things equal, we expect those to be slightly below the Hall of Fame median based on the length of his career.

# %%
# Creating boxplots of common counting stats
FirstBaseman.boxplot(column='H')
plt.scatter(1, 2135)
plt.show()
FirstBaseman.boxplot(column='BB')
plt.scatter(1, 1365)
plt.show()
FirstBaseman.boxplot(column='HR')
plt.scatter(1, 356)
plt.show()
FirstBaseman.boxplot(column='RBI')
plt.scatter(1, 1144)
plt.show()

# %% [markdown]
# Joey Votto appears to hold his own in 3 major categories while being elite in BB. Votto's elite BB rate will explain and offset his poor H count, as there will be much less opportunity to get them when He draws so many walks. Despite his well-below-average career length, Votto was just below the median value in HRs.

# %%
# Creating boxplots for common rate stats
FirstBaseman.boxplot(column='BA')
plt.scatter(1, .294)
plt.show()
FirstBaseman.boxplot(column='OBP')
plt.scatter(1, .409)
plt.show()
FirstBaseman.boxplot(column='OPS')
plt.scatter(1, .920)
plt.show()

# %% [markdown]
# Batting average is an increasingly less looked at stat in baseball today. The Hall of Fame voters have yet to catch up, so it is included in the analysis. The trend of batting average becoming obsolete will continue and may not even be much of a factor when Votto is eligible for Hall of Fame voting in 5 years. OPS has replaced batting Average in many analytic circles. OPS has become the new standard of assessing a hitter's overall ability, covering the weaknesses that batting average has. It will boost Votto's Hall of Fame resume, posting a 65 percentile score.

# %%
# Creating WAR boxplot
FirstBaseman.boxplot('WAR/pos')
plt.scatter(1, 64.5)
plt.show()

# %% [markdown]
# WAR is the most crucial stat in today's game. WAR represents the number of wins the player has added to the team compared to what a replacement player would add. WAR is the most referenced stat (for good reason) when looking at MVP voting and player comparisons. WAR is a counting stat, accumulating over a season and career. Votto's ability to produce an above-average WAR while having a below-median career length strongly indicates he belongs in the Hall of Fame.

# %%
# Obtaining percentiles
JoeyVottoH = stats.percentileofscore(FirstBaseman['H'], 2135)
JoeyVottoBB = stats.percentileofscore(FirstBaseman['BB'], 1365)
JoeyVottoHR = stats.percentileofscore(FirstBaseman['HR'], 356)
JoeyVottoRBI = stats.percentileofscore(FirstBaseman['RBI'], 1144)
JoeyVottoBA = stats.percentileofscore(FirstBaseman['BA'], .294)
JoeyVottoOBP = stats.percentileofscore(FirstBaseman['OBP'], .409)
JoeyVottoOPS = stats.percentileofscore(FirstBaseman['OPS'], .920)
JoeyVottoWAR = stats.percentileofscore(FirstBaseman['WAR/pos'], 64.4)

# Creating graph of percentiles
plt.scatter(["H", "BB", "HR", "RBI", "BA", "OBP", "OPS", "WAR/pos"], [JoeyVottoH, JoeyVottoBB, JoeyVottoHR, JoeyVottoRBI, JoeyVottoBA, JoeyVottoOBP, JoeyVottoOPS, JoeyVottoWAR])
plt.xlabel('Stat')
plt.ylabel('Percentile')
plt.ylim(0, 100)
plt.show()

# %% [markdown]
# ## Conclusion
# Joey Votto is no sure-fire Hall of Famer. He has apparent weaknesses in his resume. These include little post-season success or appearances due to being on a poor franchise most of his career. This is less important than players of other sports, as a single player in baseball has much less influence in a game than, for example, a QB in football or a player in basketball, but it is essential to note. Another weakness is his lower-than-average batting average and hits. The new wave of baseball analytics largely ignores these stats, but the Hall of Fame voters today likely will consider it when voting. Regardless, his elite OBP and good OPS should counter it. Lastly, Votto's inadequate defensive ability is something to note. He was not miserable, but definitely below average. He accumulated a -7.0 defensive WAR over the length of his career. Defensive ability, in general, is much less critical than offensive in baseball, particularly at first base, but it is important to note.
#
# Votto's resume does include many strengths. The strongest being his OPS and WAR. OPS is the standard today to analyze a player's hitting ability, and for Votto to post a great stat indicates that he belongs in the Hall of Fame. Next, Votto's WAR does similar things. The fact he was able to have above median WAR while having a much below median career length does wonders for Votto's resume and maybe the accomplishment to get him in the Hall of Fame.
#
# Looking at Votto's resume, he belongs in the Hall of Fame, and he will make it there. It is important to remember that he does not have to be better or even better than slightly worse to make the Hall of Fame. You have to showcase that he belongs. With that being said, Joey Votto has a resume that would place him as an average hall of famer. His lack of post-season play offsets his better-than-average production, giving him a resume that would put him at average Hall of Fame status.
